# %% [markdown]
#    ## 二、数据查看与预处理

# %%
import os
import numpy as np
import pandas as pd

# %%
dis= pd.read_excel('D:\JupyterWork\毕业论文\data\diseases.xlsx')

# %%
dis.info()   #查看列名、缺失情况、数据类型
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 24 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   疾病名称    8807 non-null   object
#  1   是否是常见病  8807 non-null   object
#  2   别名      8807 non-null   object
#  3   概述      8807 non-null   object
#  4   科室      8807 non-null   object
#  5   需做检查    8807 non-null   object
#  6   治疗方法    8807 non-null   object
#  7   常用药物    8807 non-null   object
#  8   一般费用    8807 non-null   object
#  9   传染性     8807 non-null   object
#  10  治愈周期    8807 non-null   object
#  11  治愈率     8807 non-null   object
#  12  患病比率    8807 non-null   object
#  13  好发人群    8807 non-null   object
#  14  相关症状    8807 non-null   object
#  15  相关疾病    8807 non-null   object
#  16  症状解析    8807 non-null   object
#  17  病因解析    8807 non-null   object
#  18  诊断解析    8805 non-null   object
#  19  治疗解析    8804 non-null   object
#  20  饮食保健    8801 non-null   object
# ...

# %%
dis.describe()    #数值型特征描述统计
# Out:
#         疾病名称 是否是常见病    别名                                                 概述  \
# count   8807   8807  8807                                               8807
# unique  8806      3  4164                                               8793
# top     胎膜早破   非常见病  None  女性生殖系统的疾病即为妇科疾病，包括外阴疾病、阴道疾病、子宫疾病、输卵管疾病、卵巢疾病等。妇...
# freq       2   5819  4641                                                  2
#
#                科室  需做检查        治疗方法    常用药物  \
# count        8807  8807        8807    8807
# unique         48  7490         998     812
# top     皮肤性病科 皮肤科    皮损  药物治疗/支持性治疗  暂无相关信息
# freq          647    47        2889    5017
#
#                                        一般费用   传染性  ...  相关症状    相关疾病  \
# count                                  8807  8807  ...  8807    8807
# unique                                 1046   285  ...  8767    8709
# top     根据不同医院，收费标准不一致，市三甲医院约（5000——10000元）  无传染性  ...    结节  暂无相关信息
# freq                                   1254  7897  ...    10      34
#
# ...

# %%
dis.drop_duplicates(inplace = True)  #删除重复行

# %%
dis.fillna('None',inplace = True)  #将缺失值替换为None

# %%
dis.info()  #再次查看列名、缺失情况、数据类型
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8807 entries, 0 to 8806
# Data columns (total 24 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   疾病名称    8807 non-null   object
#  1   是否是常见病  8807 non-null   object
#  2   别名      8807 non-null   object
#  3   概述      8807 non-null   object
#  4   科室      8807 non-null   object
#  5   需做检查    8807 non-null   object
#  6   治疗方法    8807 non-null   object
#  7   常用药物    8807 non-null   object
#  8   一般费用    8807 non-null   object
#  9   传染性     8807 non-null   object
#  10  治愈周期    8807 non-null   object
#  11  治愈率     8807 non-null   object
#  12  患病比率    8807 non-null   object
#  13  好发人群    8807 non-null   object
#  14  相关症状    8807 non-null   object
#  15  相关疾病    8807 non-null   object
#  16  症状解析    8807 non-null   object
#  17  病因解析    8807 non-null   object
#  18  诊断解析    8807 non-null   object
#  19  治疗解析    8807 non-null   object
#  20  饮食保健    8807 non-null   object
# ...

# %%
dis.to_excel('diseases_new.xlsx',encoding = 'utf-8',index = False)
